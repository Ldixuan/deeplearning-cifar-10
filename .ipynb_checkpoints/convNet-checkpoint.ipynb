# %%
import pickle
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras.metrics import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

DATA_PATH = "./cifar-10-batches-py/"
data_augmentation = False
modelName = "convNet"

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
def show_first_samples(x_train, y_train, labels_name):
    
    for i in range(4):
        imgs = x_train[i]
        img0 = imgs[0]
        img1 = imgs[1]
        img2 = imgs[2]
        i0 = Image.fromarray(img0)
        i1 = Image.fromarray(img1)
        i2 = Image.fromarray(img2)
        img = Image.merge("RGB",(i0,i1,i2))
        plt.imshow(img)
        print(labels_name[y_train[i]])
        plt.show()

# %%
def load_data():
    data_first = unpickle(DATA_PATH + "data_batch_1")
    data_x = data_first[b'data']
    data_y = data_first[b'labels']
    for i in range(2,6):
        data = unpickle(DATA_PATH + f"data_batch_{i}")
        data_x = np.vstack((data_x, data[b'data']))
        data_y += data[b'labels']
    return data_x, data_y

# %%
def create_model():
    model = Sequential()

    model.add(Conv2D( #c'est la courche de cnn
        filters = 32, #la nombre de kernel
        kernel_size = (3,3),
        data_format = "channels_first",
        padding = "same",
        input_shape = (3, 32, 32)
        ))
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size = (2,2), data_format = "channels_first", padding = "same"))
    model.add(Dropout(0.25)) #la courche de dropout, Dropout: A Simple Way to Prevent Neural Networks from Overfitting 

    model.add(Conv2D(
        filters = 32,
        kernel_size = (3,3),
        data_format = "channels_first",
        padding = "same",
        ))
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size = (2,2), data_format = "channels_first", padding = "same"))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(10))
    model.add(Activation('softmax'))

    model.compile(loss = sparse_categorical_crossentropy,
                  optimizer=Adam(),
                  metrics=['accuracy'])
    
    return model

# %%
x_train, y_train = load_data() #load the train data cifar

data_test = unpickle(DATA_PATH + "test_batch") # load the test data
x_val, y_val = data_test[b'data'], data_test[b'labels'] 

data_info = unpickle(DATA_PATH + "batches.meta") #load the data infos
labels_name = data_info[b'label_names']

x_train = x_train.reshape(-1, 3, 32, 32)
x_val = x_val.reshape(-1, 3, 32, 32)
show_first_samples(x_train, y_train, labels_name)
# Out:
# b'frog'
# b'truck'
# b'truck'
# b'deer'

# %%
y_train = np.array(y_train)
y_val = np.array(y_val)

x_train = x_train / 255.0 #transfer les data au float
x_val = x_val / 255.0

# %%
model = create_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 16, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 16, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 16, 16)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 16, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 8, 8)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 8, 8)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20490
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 30,634
# Trainable params: 30,634
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plot_model(model, f"{modelName}_log/{modelName}.png")

# %%
if data_augmentation:
    aug = ImageDataGenerator(width_shift_range = 0.2, height_shift_range = 0.2, horizontal_flip = True)
    aug.fit(x_train)
    gen = aug.flow(x_train, y_train, batch_size=128)
    history = model.fit_generator(generator=gen, 
                            steps_per_epoch=50000/128, 
                            epochs=30, 
                            validation_data=(x_val, y_val),
                            callbacks=[
                                EarlyStopping(monitor="val_accuracy", patience=2),
                                TensorBoard(log_dir=f"{modelName}_log", histogram_freq=1)
                                ])
else:
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val),
            epochs=30,
            batch_size=128,
            callbacks=[
                EarlyStopping(monitor="val_accuracy", patience=2),
                TensorBoard(log_dir=f"{modelName}_log", histogram_freq=1)
                ])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 12s 241us/sample - loss: 1.7079 - accuracy: 0.3875 - val_loss: 1.4235 - val_accuracy: 0.5022
# Epoch 2/30
# 50000/50000 [==============================] - 9s 176us/sample - loss: 1.3794 - accuracy: 0.5111 - val_loss: 1.2617 - val_accuracy: 0.5604
# Epoch 3/30
# 50000/50000 [==============================] - 10s 193us/sample - loss: 1.2475 - accuracy: 0.5638 - val_loss: 1.1595 - val_accuracy: 0.5969
# Epoch 4/30
# 50000/50000 [==============================] - 10s 210us/sample - loss: 1.1762 - accuracy: 0.5873 - val_loss: 1.1053 - val_accuracy: 0.6232
# Epoch 5/30
# 50000/50000 [==============================] - 12s 232us/sample - loss: 1.1167 - accuracy: 0.6101 - val_loss: 1.0638 - val_accuracy: 0.6330
# Epoch 6/30
# 50000/50000 [==============================] - 10s 201us/sample - loss: 1.0780 - accuracy: 0.6263 - val_loss: 1.0366 - val_accuracy: 0.6431
# Epoch 7/30
# 50000/50000 [==============================] - 10s 194us/sample - loss: 1.0441 - accuracy: 0.6371 - val_loss: 0.9999 - val_accuracy: 0.6552
# Epoch 8/30
# 50000/50000 [==============================] - 10s 209us/sample - loss: 1.0169 - accuracy: 0.6464 - val_loss: 0.9618 - val_accuracy: 0.6674
# Epoch 9/30
# 50000/50000 [==============================] - 11s 214us/sample - loss: 0.9899 - accuracy: 0.6542 - val_loss: 0.9896 - val_accuracy: 0.6533
# Epoch 10/30
# 50000/50000 [==============================] - 10s 197us/sample - loss: 0.9702 - accuracy: 0.6610 - val_loss: 0.9501 - val_accuracy: 0.6678
# Epoch 11/30
# 50000/50000 [==============================] - 10s 200us/sample - loss: 0.9587 - accuracy: 0.6674 - val_loss: 0.9204 - val_accuracy: 0.6842
# Epoch 12/30
# 50000/50000 [==============================] - 10s 205us/sample - loss: 0.9439 - accuracy: 0.6732 - val_loss: 0.9179 - val_accuracy: 0.6840
# Epoch 13/30
# 50000/50000 [==============================] - 10s 200us/sample - loss: 0.9267 - accuracy: 0.6774 - val_loss: 0.9286 - val_accuracy: 0.6778

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(f'./{modelName}_log/{modelName}_accuracy.png')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(f'./{modelName}_log/{modelName}_loss.png')
plt.show()
