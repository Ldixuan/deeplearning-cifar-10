# %% [markdown]
# # preparer l'environnement
#
# ### import des biblio

# %%
import pickle
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ### definir les variables global

# %%
DATA_PATH = "./cifar-10-batches-py/"
modelName = "rnnNet"

# %% [markdown]
# ### la fonction pour chager des fichiers

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %% [markdown]
# ### la fonction pour visualisation des data

# %%
def show_first_samples(x_train, y_train, labels_name):
    
    for i in range(4):
        imgs = x_train[i]
        img0 = imgs[0]
        img1 = imgs[1]
        img2 = imgs[2]
        i0 = Image.fromarray(img0)
        i1 = Image.fromarray(img1)
        i2 = Image.fromarray(img2)
        img = Image.merge("RGB",(i0,i1,i2))
        plt.imshow(img)
        print(labels_name[y_train[i]])
        plt.show()

# %% [markdown]
# ### la fonction pour chager des data

# %%
def load_data():
    data_first = unpickle(DATA_PATH + "data_batch_1")
    data_x = data_first[b'data']
    data_y = data_first[b'labels']
    for i in range(2,6):
        data = unpickle(DATA_PATH + f"data_batch_{i}")
        data_x = np.vstack((data_x, data[b'data']))
        data_y += data[b'labels']
    return data_x, data_y

# %% [markdown]
# # Creation de model
#
# #### Long short-term memory (LSTM) est une architecture de réseau neuronal récurrent artificiel (RNN)
# #### input shape est (nb_sample, nb_time_step, input_dim)
# #### ouput shape est (nb_sample, units)

# %%
def create_model():
    
    input_tensor = Input((3, 1024))

    lstm_tensor = Bidirectional(LSTM(128, return_sequences=True))(input_tensor)
    dropout_tensor = Dropout(0.25)(lstm_tensor)
    
    lstm_tensor = Bidirectional(LSTM(128, return_sequences=True))(dropout_tensor)
    dropout_tensor = Dropout(0.25)(lstm_tensor)
    
    lstm_tensor = Bidirectional(LSTM(128, return_sequences=False))(dropout_tensor)
    dropout_tensor = Dropout(0.25)(lstm_tensor)

    dense_tensor = Dense(10)(dropout_tensor)
    dense_activation = Activation('softmax')(dense_tensor)

    model = Model(input_tensor, dense_activation)
    
#     model = Sequential()

    
#     model.add(LSTM(512, input_shape=x_train.shape[1:]))
#     model.add(Dropout(0.25))

#     model.add(Reshape((2, 256)))

#     model.add(LSTM(100))
#     model.add(Dropout(0.25))

#     model.add(Dense(10))
#     model.add(Activation('softmax'))

    model.compile(loss = sparse_categorical_crossentropy,
                  optimizer=Adam(),
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# # Preparation des data
#
# ### chargement des data et visualisation des data

# %%
 x_train, y_train = load_data() #load the train data cifar

data_test = unpickle(DATA_PATH + "test_batch") # load the test data
x_val, y_val = data_test[b'data'], data_test[b'labels'] 

data_info = unpickle(DATA_PATH + "batches.meta") #load the data infos
labels_name = data_info[b'label_names']

x_image = x_train.reshape(-1, 3, 32, 32)

show_first_samples(x_image, y_train, labels_name)
# Out:
# b'frog'
# b'truck'
# b'truck'
# b'deer'

# %% [markdown]
# ### Formuler les data

# %%
x_train = x_train / 255.0
x_val = x_val / 255.0

x_train = x_train.reshape(-1, 3, 1024)
x_val = x_val.reshape(-1, 3, 1024)

y_train = np.array(y_train)
y_val = np.array(y_val)

# %% [markdown]
# # Visualisation du model
#
# ### la resume du model

# %%
model = create_model()
print(model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 3, 1024)]         0
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, 3, 256)            1180672
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 3, 256)            0
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, 3, 256)            394240
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 3, 256)            0
# _________________________________________________________________
# bidirectional_20 (Bidirectio (None, 256)               394240
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,971,722
# Trainable params: 1,971,722
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### tracer l'image de structure

# %%
plot_model(model, f"{modelName}_log/{modelName}.png")

# %% [markdown]
# # Compile le model
#
# ### callbacks fonction :
# #### EarlyStopping : si val_accuracy n'ai pas augmenter deplus 2 epoch, la processus va arreter.
# #### TensorBoard : une utils pour enregistrer les log

# %%
history = model.fit(x_train, y_train, validation_data=(x_val, y_val),
                epochs=30,
                batch_size=128,
                callbacks=[
                    EarlyStopping(monitor="val_accuracy", patience=2),
                    TensorBoard(log_dir=f"{modelName}_log", histogram_freq=1)
                    ])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#   128/50000 [..............................] - ETA: 2:23:07 - loss: 2.2996 - accuracy: 0.1406WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.531357). Check your callbacks.
# 50000/50000 [==============================] - 52s 1ms/sample - loss: 1.9250 - accuracy: 0.2985 - val_loss: 1.7206 - val_accuracy: 0.3828
# Epoch 2/30
# 50000/50000 [==============================] - 21s 418us/sample - loss: 1.7391 - accuracy: 0.3755 - val_loss: 1.6789 - val_accuracy: 0.4003
# Epoch 3/30
# 50000/50000 [==============================] - 22s 431us/sample - loss: 1.6537 - accuracy: 0.4079 - val_loss: 1.5843 - val_accuracy: 0.4258
# Epoch 4/30
# 50000/50000 [==============================] - 22s 436us/sample - loss: 1.5916 - accuracy: 0.4274 - val_loss: 1.5518 - val_accuracy: 0.4408
# Epoch 5/30
# 50000/50000 [==============================] - 20s 403us/sample - loss: 1.5347 - accuracy: 0.4490 - val_loss: 1.4870 - val_accuracy: 0.4651
# Epoch 6/30
# 50000/50000 [==============================] - 19s 382us/sample - loss: 1.4933 - accuracy: 0.4656 - val_loss: 1.4365 - val_accuracy: 0.4840
# Epoch 7/30
# 50000/50000 [==============================] - 21s 425us/sample - loss: 1.4442 - accuracy: 0.4833 - val_loss: 1.4197 - val_accuracy: 0.4914
# Epoch 8/30
# 50000/50000 [==============================] - 18s 364us/sample - loss: 1.4141 - accuracy: 0.4949 - val_loss: 1.3788 - val_accuracy: 0.5105
# Epoch 9/30
# 50000/50000 [==============================] - 14s 280us/sample - loss: 1.3756 - accuracy: 0.5096 - val_loss: 1.3963 - val_accuracy: 0.5028
# Epoch 10/30
# 50000/50000 [==============================] - 18s 351us/sample - loss: 1.3490 - accuracy: 0.5179 - val_loss: 1.3404 - val_accuracy: 0.5200
# Epoch 11/30
# 50000/50000 [==============================] - 19s 381us/sample - loss: 1.3218 - accuracy: 0.5267 - val_loss: 1.3552 - val_accuracy: 0.5164
# Epoch 12/30
# 50000/50000 [==============================] - 18s 368us/sample - loss: 1.2996 - accuracy: 0.5332 - val_loss: 1.3205 - val_accuracy: 0.5275
# Epoch 13/30
# 50000/50000 [==============================] - 18s 364us/sample - loss: 1.2724 - accuracy: 0.5440 - val_loss: 1.3232 - val_accuracy: 0.5327
# Epoch 14/30
# 50000/50000 [==============================] - 20s 390us/sample - loss: 1.2483 - accuracy: 0.5551 - val_loss: 1.3085 - val_accuracy: 0.5411
# Epoch 15/30
# 50000/50000 [==============================] - 17s 347us/sample - loss: 1.2282 - accuracy: 0.5612 - val_loss: 1.3027 - val_accuracy: 0.5399
# Epoch 16/30
# 50000/50000 [==============================] - 18s 351us/sample - loss: 1.2147 - accuracy: 0.5650 - val_loss: 1.3139 - val_accuracy: 0.5405

# %% [markdown]
# # Visualisation des resultat
#
# ### visualisation de accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(f'./{modelName}_log/{modelName}_accuracy.png')
plt.show()

# %% [markdown]
# ### visualisation de loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(f'./{modelName}_log/{modelName}_loss.png')
plt.show()
