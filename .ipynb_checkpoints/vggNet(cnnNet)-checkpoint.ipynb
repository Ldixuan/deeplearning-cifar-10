# %% [markdown]
# # preparer l'environnement
#
# ### import des biblio

# %%
import pickle
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras.metrics import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ### definir les variables global

# %%
DATA_PATH = "./cifar-10-batches-py/"
data_augmentation = False
modelName = "vggNet"

# %% [markdown]
# ### la fonction pour chager des fichiers

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %% [markdown]
# ### la fonction pour visualisation des data

# %%
def show_first_samples(x_train, y_train, labels_name):
    
    for i in range(4):
        imgs = x_train[i]
        img0 = imgs[0]
        img1 = imgs[1]
        img2 = imgs[2]
        i0 = Image.fromarray(img0)
        i1 = Image.fromarray(img1)
        i2 = Image.fromarray(img2)
        img = Image.merge("RGB",(i0,i1,i2))
        plt.imshow(img)
        print(labels_name[y_train[i]])
        plt.show()

# %% [markdown]
# ### la fonction pour chager des data

# %%
def load_data():
    data_first = unpickle(DATA_PATH + "data_batch_1")
    data_x = data_first[b'data']
    data_y = data_first[b'labels']
    for i in range(2,6):
        data = unpickle(DATA_PATH + f"data_batch_{i}")
        data_x = np.vstack((data_x, data[b'data']))
        data_y += data[b'labels']
    return data_x, data_y

# %% [markdown]
# # Creation de model
#
# #### vgg 16 est une architecture de réseau cnn
# #### l'architecture de vgg16 est 2 fois (2 courche de cnn + 1 courche de maxPooling) + 3 fois (3 courche de cnn + 1 courche de maxPooling) + 3 courche de dense. il y a 16 courche de cacher donc il s'appelle vgg 16
# #### pour simplifier, j'ai utilise 1 fois (2 courche de cnn + 1 courche de maxPooling) + 1 fois (2 courche de cnn + 1 courche de maxPooling) + 2 courche de dense.

# %%
def create_model():
    model = Sequential()

    model.add(Conv2D(
        filters = 64,
        kernel_size = (3,3),
        data_format = "channels_first",
        padding = "same",
        input_shape = (3, 32, 32)
        ))
    model.add(Activation('relu'))

    model.add(Conv2D(
        filters = 64,
        kernel_size = (3,3),
        data_format = "channels_first",
        padding = "same",
        input_shape = (3, 32, 32)
        ))
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size = (2,2), data_format = "channels_first", padding = "same"))
    model.add(Dropout(0.25))

    model.add(Conv2D(filters = 128,
        kernel_size = (3,3),
        data_format = "channels_first",
        padding = "same",
    ))
    model.add(Activation('relu'))

    model.add(Conv2D(
        filters = 128,
        kernel_size = (3,3),
        data_format = "channels_first",
        padding = "same",
    ))
    

    model.add(Conv2D(
        filters = 128,
        kernel_size = (3,3),
        data_format = "channels_first",
        padding = "same",
    ))
    model.add(Activation('relu'))

    model.add(MaxPooling2D(pool_size = (2,2), data_format = "channels_first", padding = "same"))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(10))
    model.add(Activation('softmax'))

    model.compile(loss = sparse_categorical_crossentropy,
                  optimizer=Adam(),
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# # Preparation des data
#
# ### chargement des data et visualisation des data

# %%
x_train, y_train = load_data() #load the train data cifar

data_test = unpickle(DATA_PATH + "test_batch") # load the test data
x_val, y_val = data_test[b'data'], data_test[b'labels'] 

data_info = unpickle(DATA_PATH + "batches.meta") #load the data infos
labels_name = data_info[b'label_names']

x_train = x_train.reshape(-1, 3, 32, 32)
x_val = x_val.reshape(-1, 3, 32, 32)

y_train = np.array(y_train)
y_val = np.array(y_val)

show_first_samples(x_train, y_train, labels_name)

x_train = x_train / 255.0
x_val = x_val / 255.0
# Out:
# b'frog'
# b'truck'
# b'truck'
# b'deer'

# %% [markdown]
# # Visualisation du model
#
# ### la resume du model

# %%
model = create_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 32, 32)        1792
# _________________________________________________________________
# activation (Activation)      (None, 64, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 32, 32)        36928
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 32, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 16, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 16, 16)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 128, 16, 16)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 16, 16)       147584
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 16, 16)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 128, 16, 16)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 8, 8)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 8, 8)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 4,607,690
# Trainable params: 4,607,690
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### tracer l'image de structure

# %%
plot_model(model, f"{modelName}_log/{modelName}.png")

# %% [markdown]
# # Compile le model
#
# ### callbacks fonction :
# #### EarlyStopping : si val_accuracy n'ai pas augmenter deplus 2 epoch, la processus va arreter.
# #### TensorBoard : une utils pour enregistrer les log

# %%
if data_augmentation:
    aug = ImageDataGenerator(width_shift_range = 0.2, height_shift_range = 0.2, horizontal_flip = True)
    aug.fit(x_train)
    gen = aug.flow(x_train, y_train, batch_size=128)
    history = model.fit_generator(generator=gen, 
                            steps_per_epoch=50000/128, 
                            epochs=30, 
                            validation_data=(x_val, y_val),
                            callbacks=[
                                EarlyStopping(monitor="val_accuracy", patience=2),
                                TensorBoard(log_dir=f"{modelName}_log", histogram_freq=1)
                                ])
else:
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val),
            epochs=30,
            batch_size=128,
            callbacks=[
                EarlyStopping(monitor="val_accuracy", patience=2),
                TensorBoard(log_dir=f"{modelName}_log", histogram_freq=1)
                ])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
#   128/50000 [..............................] - ETA: 1:04:15 - loss: 2.3192 - accuracy: 0.0703WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.165613). Check your callbacks.
# 50000/50000 [==============================] - 83s 2ms/sample - loss: 1.5537 - accuracy: 0.4295 - val_loss: 1.1381 - val_accuracy: 0.5908
# Epoch 2/30
# 50000/50000 [==============================] - 94s 2ms/sample - loss: 1.1200 - accuracy: 0.6011 - val_loss: 0.9644 - val_accuracy: 0.6563
# Epoch 3/30
# 50000/50000 [==============================] - 92s 2ms/sample - loss: 0.9295 - accuracy: 0.6728 - val_loss: 0.8586 - val_accuracy: 0.7046
# Epoch 4/30
# 50000/50000 [==============================] - 81s 2ms/sample - loss: 0.8138 - accuracy: 0.7126 - val_loss: 0.7346 - val_accuracy: 0.7441
# Epoch 5/30
# 50000/50000 [==============================] - 79s 2ms/sample - loss: 0.7305 - accuracy: 0.7440 - val_loss: 0.6894 - val_accuracy: 0.7636
# Epoch 6/30
# 50000/50000 [==============================] - 77s 2ms/sample - loss: 0.6591 - accuracy: 0.7696 - val_loss: 0.6503 - val_accuracy: 0.7757
# Epoch 7/30
# 50000/50000 [==============================] - 71s 1ms/sample - loss: 0.6099 - accuracy: 0.7852 - val_loss: 0.7041 - val_accuracy: 0.7618
# Epoch 8/30
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.5632 - accuracy: 0.8025 - val_loss: 0.6318 - val_accuracy: 0.7877
# Epoch 9/30
# 50000/50000 [==============================] - 75s 1ms/sample - loss: 0.5244 - accuracy: 0.8133 - val_loss: 0.6330 - val_accuracy: 0.7845
# Epoch 10/30
# 50000/50000 [==============================] - 75s 2ms/sample - loss: 0.4948 - accuracy: 0.8268 - val_loss: 0.6198 - val_accuracy: 0.7956
# Epoch 11/30
# 50000/50000 [==============================] - 72s 1ms/sample - loss: 0.4625 - accuracy: 0.8375 - val_loss: 0.6829 - val_accuracy: 0.7876
# Epoch 12/30
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 0.4240 - accuracy: 0.8499 - val_loss: 0.6340 - val_accuracy: 0.7975
# Epoch 13/30
# 50000/50000 [==============================] - 74s 1ms/sample - loss: 0.4145 - accuracy: 0.8541 - val_loss: 0.6261 - val_accuracy: 0.7966
# Epoch 14/30
# 50000/50000 [==============================] - 75s 2ms/sample - loss: 0.3886 - accuracy: 0.8602 - val_loss: 0.6344 - val_accuracy: 0.7947

# %% [markdown]
# # Visualisation des resultat
#
# ### visualisation de accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(f'./{modelName}_log/{modelName}_accuracy.png')
plt.show()

# %% [markdown]
# ### visualisation de loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(f'./{modelName}_log/{modelName}_loss.png')
plt.show()
